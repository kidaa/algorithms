# %%
import pandas as pd
# %matplotlib inline

# %% [markdown]
# ###A simple example to illustrate the intuition behind dummy variables

# %%
df = pd.DataFrame({'key':['b','b','a','c','a','b'],'data1':range(6)})

# %%
df
# Out:
#    data1 key
# 0      0   b
# 1      1   b
# 2      2   a
# 3      3   c
# 4      4   a
# 5      5   b

# %%
pd.get_dummies(df['key'],prefix='key')
# Out:
#    key_a  key_b  key_c
# 0      0      1      0
# 1      0      1      0
# 2      1      0      0
# 3      0      0      1
# 4      1      0      0
# 5      0      1      0

# %% [markdown]
# ###Now we have a matrix of values based on the presence of absence of the attribute value in our dataset

# %% [markdown]
# ###Now let's look at another example using our flight data

# %%
df = pd.read_csv('data/ontime_reports_may_2015_ny.csv')
df
# Out:
#        YEAR  MONTH  DAY_OF_MONTH CARRIER  FL_NUM ORIGIN DEST  DEP_DELAY  \
# 0      2015      5             1      AA      44    LAS  JFK         -6
# 1      2015      5             2      AA      44    LAS  JFK         -8
# 2      2015      5             3      AA      44    LAS  JFK          0
# 3      2015      5             4      AA      44    LAS  JFK        -11
# 4      2015      5             5      AA      44    LAS  JFK         -4
# 5      2015      5             6      AA      44    LAS  JFK         -5
# 6      2015      5             7      AA      44    SEA  JFK         -2
# 7      2015      5             8      AA      44    SEA  JFK         -3
# 8      2015      5             9      AA      44    SEA  JFK         -6
# 9      2015      5            10      AA      44    SEA  JFK         38
# 10     2015      5            11      AA      44    SEA  JFK         -2
# 11     2015      5            12      AA      44    SEA  JFK         19
# 12     2015      5            13      AA      44    SEA  JFK         -1
# 13     2015      5            14      AA      44    SEA  JFK        175
# 14     2015      5            15      AA      44    SEA  JFK         -1
# 15     2015      5            16      AA      44    SEA  JFK          0
# 16     2015      5            17      AA      44    SEA  JFK         -4
# 17     2015      5            18      AA      44    SEA  JFK         -5
# 18     2015      5            19      AA      44    SEA  JFK         -4
# 19     2015      5            20      AA      44    SEA  JFK         -1
# 20     2015      5            21      AA      44    SEA  JFK        -10
# 21     2015      5            22      AA      44    SEA  JFK         85
# 22     2015      5            23      AA      44    SEA  JFK          3
# 23     2015      5            24      AA      44    SEA  JFK          1
# 24     2015      5            25      AA      44    SEA  JFK         -2
# 25     2015      5            26      AA      44    SEA  JFK         26
# 26     2015      5            27      AA      44    SEA  JFK         -2
# 27     2015      5            28      AA      44    SEA  JFK         -4
# 28     2015      5            29      AA      44    SEA  JFK         -9
# 29     2015      5            30      AA      44    SEA  JFK         -3
# ...     ...    ...           ...     ...     ...    ...  ...        ...
# 45618  2015      5            31      WN    2632    MCO  BUF         -3
# 45619  2015      5            31      WN     293    MCO  ISP         -3
# 45620  2015      5            31      WN     325    MCO  ISP          6
# 45621  2015      5            31      WN     426    MCO  ISP         -5
# 45622  2015      5            31      WN    4486    MCO  ISP         20
# 45623  2015      5            31      WN    3935    MCO  ROC         -1
# 45624  2015      5            31      WN     103    MDW  ALB          5
# 45625  2015      5            31      WN    1461    MDW  ALB         58
# 45626  2015      5            31      WN     134    MDW  BUF         33
# 45627  2015      5            31      WN     615    MDW  BUF          1
# 45628  2015      5            31      WN    2241    MDW  BUF         13
# 45629  2015      5            31      WN      33    MDW  LGA          0
# 45630  2015      5            31      WN     682    MDW  LGA         31
# 45631  2015      5            31      WN     803    MDW  LGA         35
# 45632  2015      5            31      WN    1945    MDW  LGA         61
# 45633  2015      5            31      WN    2778    MDW  LGA         -2
# 45634  2015      5            31      WN    4365    MDW  LGA        150
# 45635  2015      5            31      WN     292    MDW  ROC         10
# 45636  2015      5            31      WN    2229    MDW  ROC          0
# 45637  2015      5            31      WN    1208    MKE  LGA          8
# 45638  2015      5            31      WN    3391    MKE  LGA        135
# 45639  2015      5            31      WN    1194    STL  LGA         -4
# 45640  2015      5            31      WN    1986    STL  LGA        NaN
# 45641  2015      5            31      WN    3741    STL  LGA         41
# 45642  2015      5            31      WN     854    TPA  ALB         -1
# 45643  2015      5            31      WN     127    TPA  BUF         -5
# 45644  2015      5            31      WN    2160    TPA  BUF         50
# 45645  2015      5            31      WN    2423    TPA  ISP          3
# 45646  2015      5            31      WN    4390    TPA  ISP         -4
# 45647  2015      5            31      WN    3874    TPA  ROC          2
#
#        ARR_DELAY  CANCELLED     ...      DIVERTED  ACTUAL_ELAPSED_TIME  \
# 0            -17          0     ...             0                  294
# 1            -14          0     ...             0                  299
# 2            -11          0     ...             0                  294
# 3              4          0     ...             0                  320
# 4            -18          0     ...             0                  291
# 5             -6          0     ...             0                  304
# 6            -11          0     ...             0                  319
# 7            -15          0     ...             0                  316
# 8              5          0     ...             0                  339
# 9             31          0     ...             0                  321
# 10           -11          0     ...             0                  319
# 11           -10          0     ...             0                  299
# 12           -10          0     ...             0                  319
# 13           157          0     ...             0                  310
# 14            -8          0     ...             0                  321
# 15             5          0     ...             0                  333
# 16             7          0     ...             0                  339
# 17           -10          0     ...             0                  323
# 18           -24          0     ...             0                  308
# 19            -8          0     ...             0                  321
# 20           -29          0     ...             0                  309
# 21            89          0     ...             0                  332
# 22           -16          0     ...             0                  309
# 23           -13          0     ...             0                  314
# 24           -11          0     ...             0                  319
# 25            30          0     ...             0                  332
# 26             8          0     ...             0                  338
# 27            -8          0     ...             0                  324
# 28           -20          0     ...             0                  317
# 29           -10          0     ...             0                  321
# ...          ...        ...     ...           ...                  ...
# 45618        -13          0     ...             0                  145
# 45619         -7          0     ...             0                  151
# 45620          7          0     ...             0                  151
# 45621        -10          0     ...             0                  145
# 45622         17          0     ...             0                  147
# 45623         -7          0     ...             0                  149
# 45624          0          0     ...             0                  110
# 45625         52          0     ...             0                  109
# 45626         24          0     ...             0                   81
# 45627        -11          0     ...             0                   78
# 45628        -13          0     ...             0                   74
# 45629         -4          0     ...             0                  126
# 45630        NaN          0     ...             1                  NaN
# 45631        NaN          1     ...             0                  NaN
# 45632        NaN          0     ...             1                  NaN
# 45633         -5          0     ...             0                  122
# 45634        138          0     ...             0                  118
# 45635          1          0     ...             0                   81
# 45636         -8          0     ...             0                   87
# 45637         13          0     ...             0                  140
# 45638        NaN          0     ...             1                  NaN
# 45639        -18          0     ...             0                  131
# 45640        NaN          1     ...             0                  NaN
# 45641        NaN          0     ...             1                  NaN
# 45642          7          0     ...             0                  178
# 45643         -9          0     ...             0                  151
# 45644         50          0     ...             0                  155
# 45645          3          0     ...             0                  155
# 45646        -14          0     ...             0                  155
# 45647         -2          0     ...             0                  156
#
#        AIR_TIME  DISTANCE  CARRIER_DELAY  WEATHER_DELAY  NAS_DELAY  \
# 0           273      2248            NaN            NaN        NaN
# 1           280      2248            NaN            NaN        NaN
# 2           274      2248            NaN            NaN        NaN
# 3           275      2248            NaN            NaN        NaN
# 4           270      2248            NaN            NaN        NaN
# 5           279      2248            NaN            NaN        NaN
# 6           297      2422            NaN            NaN        NaN
# 7           293      2422            NaN            NaN        NaN
# 8           307      2422            NaN            NaN        NaN
# 9           301      2422              0             31          0
# 10          291      2422            NaN            NaN        NaN
# 11          283      2422            NaN            NaN        NaN
# 12          287      2422            NaN            NaN        NaN
# 13          291      2422            157              0          0
# 14          295      2422            NaN            NaN        NaN
# 15          303      2422            NaN            NaN        NaN
# 16          313      2422            NaN            NaN        NaN
# 17          300      2422            NaN            NaN        NaN
# 18          280      2422            NaN            NaN        NaN
# 19          291      2422            NaN            NaN        NaN
# 20          283      2422            NaN            NaN        NaN
# 21          298      2422             85              0          4
# 22          278      2422            NaN            NaN        NaN
# 23          292      2422            NaN            NaN        NaN
# 24          298      2422            NaN            NaN        NaN
# 25          308      2422             26              0          4
# 26          308      2422            NaN            NaN        NaN
# 27          289      2422            NaN            NaN        NaN
# 28          297      2422            NaN            NaN        NaN
# 29          295      2422            NaN            NaN        NaN
# ...         ...       ...            ...            ...        ...
# 45618       131      1011            NaN            NaN        NaN
# 45619       134       971            NaN            NaN        NaN
# 45620       134       971            NaN            NaN        NaN
# 45621       133       971            NaN            NaN        NaN
# 45622       131       971             17              0          0
# 45623       134      1033            NaN            NaN        NaN
# 45624        88       717            NaN            NaN        NaN
# 45625        87       717              0             52          0
# 45626        61       468             24              0          0
# 45627        61       468            NaN            NaN        NaN
# 45628        59       468            NaN            NaN        NaN
# 45629        96       725            NaN            NaN        NaN
# 45630       NaN       725            NaN            NaN        NaN
# 45631       NaN       725            NaN            NaN        NaN
# 45632       NaN       725            NaN            NaN        NaN
# 45633        95       725            NaN            NaN        NaN
# 45634        99       725            138              0          0
# 45635        66       523            NaN            NaN        NaN
# 45636        68       523            NaN            NaN        NaN
# 45637       107       738            NaN            NaN        NaN
# 45638       NaN       738            NaN            NaN        NaN
# 45639       114       888            NaN            NaN        NaN
# 45640       NaN       888            NaN            NaN        NaN
# 45641       NaN       888            NaN            NaN        NaN
# 45642       151      1130            NaN            NaN        NaN
# 45643       136      1053            NaN            NaN        NaN
# 45644       142      1053              0             12          0
# 45645       140      1034            NaN            NaN        NaN
# 45646       143      1034            NaN            NaN        NaN
# 45647       143      1079            NaN            NaN        NaN
#
#        SECURITY_DELAY  LATE_AIRCRAFT_DELAY  Unnamed: 20
# 0                 NaN                  NaN          NaN
# 1                 NaN                  NaN          NaN
# 2                 NaN                  NaN          NaN
# 3                 NaN                  NaN          NaN
# 4                 NaN                  NaN          NaN
# 5                 NaN                  NaN          NaN
# 6                 NaN                  NaN          NaN
# 7                 NaN                  NaN          NaN
# 8                 NaN                  NaN          NaN
# 9                   0                    0          NaN
# 10                NaN                  NaN          NaN
# 11                NaN                  NaN          NaN
# 12                NaN                  NaN          NaN
# 13                  0                    0          NaN
# 14                NaN                  NaN          NaN
# 15                NaN                  NaN          NaN
# 16                NaN                  NaN          NaN
# 17                NaN                  NaN          NaN
# 18                NaN                  NaN          NaN
# 19                NaN                  NaN          NaN
# 20                NaN                  NaN          NaN
# 21                  0                    0          NaN
# 22                NaN                  NaN          NaN
# 23                NaN                  NaN          NaN
# 24                NaN                  NaN          NaN
# 25                  0                    0          NaN
# 26                NaN                  NaN          NaN
# 27                NaN                  NaN          NaN
# 28                NaN                  NaN          NaN
# 29                NaN                  NaN          NaN
# ...               ...                  ...          ...
# 45618             NaN                  NaN          NaN
# 45619             NaN                  NaN          NaN
# 45620             NaN                  NaN          NaN
# 45621             NaN                  NaN          NaN
# 45622               0                    0          NaN
# 45623             NaN                  NaN          NaN
# 45624             NaN                  NaN          NaN
# 45625               0                    0          NaN
# 45626               0                    0          NaN
# 45627             NaN                  NaN          NaN
# 45628             NaN                  NaN          NaN
# 45629             NaN                  NaN          NaN
# 45630             NaN                  NaN          NaN
# 45631             NaN                  NaN          NaN
# 45632             NaN                  NaN          NaN
# 45633             NaN                  NaN          NaN
# 45634               0                    0          NaN
# 45635             NaN                  NaN          NaN
# 45636             NaN                  NaN          NaN
# 45637             NaN                  NaN          NaN
# 45638             NaN                  NaN          NaN
# 45639             NaN                  NaN          NaN
# 45640             NaN                  NaN          NaN
# 45641             NaN                  NaN          NaN
# 45642             NaN                  NaN          NaN
# 45643             NaN                  NaN          NaN
# 45644               0                   38          NaN
# 45645             NaN                  NaN          NaN
# 45646             NaN                  NaN          NaN
# 45647             NaN                  NaN          NaN
#
# [45648 rows x 21 columns]

# %%
#count number of NaNs in column
df['DEP_DELAY'].isnull().sum()
# Out:
# 728

# %%
#calculate the percentage this represents of the total number of instances
df['DEP_DELAY'].isnull().sum()/df['DEP_DELAY'].sum()
# Out:
# 0.0014866851821597779

# %% [markdown]
# ###We could explore whether the NaNs are actually zero delays, but we'll just filter them out for now, especially since they represent such a small number of instances

# %%
#filter DEP_DELAY NaNs
df = df[pd.notnull(df['DEP_DELAY'])]
df
# Out:
#        YEAR  MONTH  DAY_OF_MONTH CARRIER  FL_NUM ORIGIN DEST  DEP_DELAY  \
# 0      2015      5             1      AA      44    LAS  JFK         -6
# 1      2015      5             2      AA      44    LAS  JFK         -8
# 2      2015      5             3      AA      44    LAS  JFK          0
# 3      2015      5             4      AA      44    LAS  JFK        -11
# 4      2015      5             5      AA      44    LAS  JFK         -4
# 5      2015      5             6      AA      44    LAS  JFK         -5
# 6      2015      5             7      AA      44    SEA  JFK         -2
# 7      2015      5             8      AA      44    SEA  JFK         -3
# 8      2015      5             9      AA      44    SEA  JFK         -6
# 9      2015      5            10      AA      44    SEA  JFK         38
# 10     2015      5            11      AA      44    SEA  JFK         -2
# 11     2015      5            12      AA      44    SEA  JFK         19
# 12     2015      5            13      AA      44    SEA  JFK         -1
# 13     2015      5            14      AA      44    SEA  JFK        175
# 14     2015      5            15      AA      44    SEA  JFK         -1
# 15     2015      5            16      AA      44    SEA  JFK          0
# 16     2015      5            17      AA      44    SEA  JFK         -4
# 17     2015      5            18      AA      44    SEA  JFK         -5
# 18     2015      5            19      AA      44    SEA  JFK         -4
# 19     2015      5            20      AA      44    SEA  JFK         -1
# 20     2015      5            21      AA      44    SEA  JFK        -10
# 21     2015      5            22      AA      44    SEA  JFK         85
# 22     2015      5            23      AA      44    SEA  JFK          3
# 23     2015      5            24      AA      44    SEA  JFK          1
# 24     2015      5            25      AA      44    SEA  JFK         -2
# 25     2015      5            26      AA      44    SEA  JFK         26
# 26     2015      5            27      AA      44    SEA  JFK         -2
# 27     2015      5            28      AA      44    SEA  JFK         -4
# 28     2015      5            29      AA      44    SEA  JFK         -9
# 29     2015      5            30      AA      44    SEA  JFK         -3
# ...     ...    ...           ...     ...     ...    ...  ...        ...
# 45617  2015      5            31      WN    2423    MCO  BUF         -1
# 45618  2015      5            31      WN    2632    MCO  BUF         -3
# 45619  2015      5            31      WN     293    MCO  ISP         -3
# 45620  2015      5            31      WN     325    MCO  ISP          6
# 45621  2015      5            31      WN     426    MCO  ISP         -5
# 45622  2015      5            31      WN    4486    MCO  ISP         20
# 45623  2015      5            31      WN    3935    MCO  ROC         -1
# 45624  2015      5            31      WN     103    MDW  ALB          5
# 45625  2015      5            31      WN    1461    MDW  ALB         58
# 45626  2015      5            31      WN     134    MDW  BUF         33
# 45627  2015      5            31      WN     615    MDW  BUF          1
# 45628  2015      5            31      WN    2241    MDW  BUF         13
# 45629  2015      5            31      WN      33    MDW  LGA          0
# 45630  2015      5            31      WN     682    MDW  LGA         31
# 45631  2015      5            31      WN     803    MDW  LGA         35
# 45632  2015      5            31      WN    1945    MDW  LGA         61
# 45633  2015      5            31      WN    2778    MDW  LGA         -2
# 45634  2015      5            31      WN    4365    MDW  LGA        150
# 45635  2015      5            31      WN     292    MDW  ROC         10
# 45636  2015      5            31      WN    2229    MDW  ROC          0
# 45637  2015      5            31      WN    1208    MKE  LGA          8
# 45638  2015      5            31      WN    3391    MKE  LGA        135
# 45639  2015      5            31      WN    1194    STL  LGA         -4
# 45641  2015      5            31      WN    3741    STL  LGA         41
# 45642  2015      5            31      WN     854    TPA  ALB         -1
# 45643  2015      5            31      WN     127    TPA  BUF         -5
# 45644  2015      5            31      WN    2160    TPA  BUF         50
# 45645  2015      5            31      WN    2423    TPA  ISP          3
# 45646  2015      5            31      WN    4390    TPA  ISP         -4
# 45647  2015      5            31      WN    3874    TPA  ROC          2
#
#        ARR_DELAY  CANCELLED     ...      DIVERTED  ACTUAL_ELAPSED_TIME  \
# 0            -17          0     ...             0                  294
# 1            -14          0     ...             0                  299
# 2            -11          0     ...             0                  294
# 3              4          0     ...             0                  320
# 4            -18          0     ...             0                  291
# 5             -6          0     ...             0                  304
# 6            -11          0     ...             0                  319
# 7            -15          0     ...             0                  316
# 8              5          0     ...             0                  339
# 9             31          0     ...             0                  321
# 10           -11          0     ...             0                  319
# 11           -10          0     ...             0                  299
# 12           -10          0     ...             0                  319
# 13           157          0     ...             0                  310
# 14            -8          0     ...             0                  321
# 15             5          0     ...             0                  333
# 16             7          0     ...             0                  339
# 17           -10          0     ...             0                  323
# 18           -24          0     ...             0                  308
# 19            -8          0     ...             0                  321
# 20           -29          0     ...             0                  309
# 21            89          0     ...             0                  332
# 22           -16          0     ...             0                  309
# 23           -13          0     ...             0                  314
# 24           -11          0     ...             0                  319
# 25            30          0     ...             0                  332
# 26             8          0     ...             0                  338
# 27            -8          0     ...             0                  324
# 28           -20          0     ...             0                  317
# 29           -10          0     ...             0                  321
# ...          ...        ...     ...           ...                  ...
# 45617         -2          0     ...             0                  154
# 45618        -13          0     ...             0                  145
# 45619         -7          0     ...             0                  151
# 45620          7          0     ...             0                  151
# 45621        -10          0     ...             0                  145
# 45622         17          0     ...             0                  147
# 45623         -7          0     ...             0                  149
# 45624          0          0     ...             0                  110
# 45625         52          0     ...             0                  109
# 45626         24          0     ...             0                   81
# 45627        -11          0     ...             0                   78
# 45628        -13          0     ...             0                   74
# 45629         -4          0     ...             0                  126
# 45630        NaN          0     ...             1                  NaN
# 45631        NaN          1     ...             0                  NaN
# 45632        NaN          0     ...             1                  NaN
# 45633         -5          0     ...             0                  122
# 45634        138          0     ...             0                  118
# 45635          1          0     ...             0                   81
# 45636         -8          0     ...             0                   87
# 45637         13          0     ...             0                  140
# 45638        NaN          0     ...             1                  NaN
# 45639        -18          0     ...             0                  131
# 45641        NaN          0     ...             1                  NaN
# 45642          7          0     ...             0                  178
# 45643         -9          0     ...             0                  151
# 45644         50          0     ...             0                  155
# 45645          3          0     ...             0                  155
# 45646        -14          0     ...             0                  155
# 45647         -2          0     ...             0                  156
#
#        AIR_TIME  DISTANCE  CARRIER_DELAY  WEATHER_DELAY  NAS_DELAY  \
# 0           273      2248            NaN            NaN        NaN
# 1           280      2248            NaN            NaN        NaN
# 2           274      2248            NaN            NaN        NaN
# 3           275      2248            NaN            NaN        NaN
# 4           270      2248            NaN            NaN        NaN
# 5           279      2248            NaN            NaN        NaN
# 6           297      2422            NaN            NaN        NaN
# 7           293      2422            NaN            NaN        NaN
# 8           307      2422            NaN            NaN        NaN
# 9           301      2422              0             31          0
# 10          291      2422            NaN            NaN        NaN
# 11          283      2422            NaN            NaN        NaN
# 12          287      2422            NaN            NaN        NaN
# 13          291      2422            157              0          0
# 14          295      2422            NaN            NaN        NaN
# 15          303      2422            NaN            NaN        NaN
# 16          313      2422            NaN            NaN        NaN
# 17          300      2422            NaN            NaN        NaN
# 18          280      2422            NaN            NaN        NaN
# 19          291      2422            NaN            NaN        NaN
# 20          283      2422            NaN            NaN        NaN
# 21          298      2422             85              0          4
# 22          278      2422            NaN            NaN        NaN
# 23          292      2422            NaN            NaN        NaN
# 24          298      2422            NaN            NaN        NaN
# 25          308      2422             26              0          4
# 26          308      2422            NaN            NaN        NaN
# 27          289      2422            NaN            NaN        NaN
# 28          297      2422            NaN            NaN        NaN
# 29          295      2422            NaN            NaN        NaN
# ...         ...       ...            ...            ...        ...
# 45617       134      1011            NaN            NaN        NaN
# 45618       131      1011            NaN            NaN        NaN
# 45619       134       971            NaN            NaN        NaN
# 45620       134       971            NaN            NaN        NaN
# 45621       133       971            NaN            NaN        NaN
# 45622       131       971             17              0          0
# 45623       134      1033            NaN            NaN        NaN
# 45624        88       717            NaN            NaN        NaN
# 45625        87       717              0             52          0
# 45626        61       468             24              0          0
# 45627        61       468            NaN            NaN        NaN
# 45628        59       468            NaN            NaN        NaN
# 45629        96       725            NaN            NaN        NaN
# 45630       NaN       725            NaN            NaN        NaN
# 45631       NaN       725            NaN            NaN        NaN
# 45632       NaN       725            NaN            NaN        NaN
# 45633        95       725            NaN            NaN        NaN
# 45634        99       725            138              0          0
# 45635        66       523            NaN            NaN        NaN
# 45636        68       523            NaN            NaN        NaN
# 45637       107       738            NaN            NaN        NaN
# 45638       NaN       738            NaN            NaN        NaN
# 45639       114       888            NaN            NaN        NaN
# 45641       NaN       888            NaN            NaN        NaN
# 45642       151      1130            NaN            NaN        NaN
# 45643       136      1053            NaN            NaN        NaN
# 45644       142      1053              0             12          0
# 45645       140      1034            NaN            NaN        NaN
# 45646       143      1034            NaN            NaN        NaN
# 45647       143      1079            NaN            NaN        NaN
#
#        SECURITY_DELAY  LATE_AIRCRAFT_DELAY  Unnamed: 20
# 0                 NaN                  NaN          NaN
# 1                 NaN                  NaN          NaN
# 2                 NaN                  NaN          NaN
# 3                 NaN                  NaN          NaN
# 4                 NaN                  NaN          NaN
# 5                 NaN                  NaN          NaN
# 6                 NaN                  NaN          NaN
# 7                 NaN                  NaN          NaN
# 8                 NaN                  NaN          NaN
# 9                   0                    0          NaN
# 10                NaN                  NaN          NaN
# 11                NaN                  NaN          NaN
# 12                NaN                  NaN          NaN
# 13                  0                    0          NaN
# 14                NaN                  NaN          NaN
# 15                NaN                  NaN          NaN
# 16                NaN                  NaN          NaN
# 17                NaN                  NaN          NaN
# 18                NaN                  NaN          NaN
# 19                NaN                  NaN          NaN
# 20                NaN                  NaN          NaN
# 21                  0                    0          NaN
# 22                NaN                  NaN          NaN
# 23                NaN                  NaN          NaN
# 24                NaN                  NaN          NaN
# 25                  0                    0          NaN
# 26                NaN                  NaN          NaN
# 27                NaN                  NaN          NaN
# 28                NaN                  NaN          NaN
# 29                NaN                  NaN          NaN
# ...               ...                  ...          ...
# 45617             NaN                  NaN          NaN
# 45618             NaN                  NaN          NaN
# 45619             NaN                  NaN          NaN
# 45620             NaN                  NaN          NaN
# 45621             NaN                  NaN          NaN
# 45622               0                    0          NaN
# 45623             NaN                  NaN          NaN
# 45624             NaN                  NaN          NaN
# 45625               0                    0          NaN
# 45626               0                    0          NaN
# 45627             NaN                  NaN          NaN
# 45628             NaN                  NaN          NaN
# 45629             NaN                  NaN          NaN
# 45630             NaN                  NaN          NaN
# 45631             NaN                  NaN          NaN
# 45632             NaN                  NaN          NaN
# 45633             NaN                  NaN          NaN
# 45634               0                    0          NaN
# 45635             NaN                  NaN          NaN
# 45636             NaN                  NaN          NaN
# 45637             NaN                  NaN          NaN
# 45638             NaN                  NaN          NaN
# 45639             NaN                  NaN          NaN
# 45641             NaN                  NaN          NaN
# 45642             NaN                  NaN          NaN
# 45643             NaN                  NaN          NaN
# 45644               0                   38          NaN
# 45645             NaN                  NaN          NaN
# 45646             NaN                  NaN          NaN
# 45647             NaN                  NaN          NaN
#
# [44920 rows x 21 columns]

# %% [markdown]
# ###We can discretize the continuous DEP_DELAY value by giving it a value of 0 if it's delayed and a 1 if it's not. We record this value into a separate column. (We could also code -1 for early, 0 for ontime, and 1 for late)

# %%
#code whether delay or not delayed
df['IS_DELAYED'] = df['DEP_DELAY'].apply(lambda x: 1 if x>0 else 0 )
# Out:
# /Users/jiachuan/anaconda/lib/python2.7/site-packages/IPython/kernel/__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from IPython.kernel.zmq import kernelapp as app

# %%
#Let's check that our column was created properly
df[['DEP_DELAY','IS_DELAYED']]
# Out:
#        DEP_DELAY  IS_DELAYED
# 0             -6           0
# 1             -8           0
# 2              0           0
# 3            -11           0
# 4             -4           0
# 5             -5           0
# 6             -2           0
# 7             -3           0
# 8             -6           0
# 9             38           1
# 10            -2           0
# 11            19           1
# 12            -1           0
# 13           175           1
# 14            -1           0
# 15             0           0
# 16            -4           0
# 17            -5           0
# 18            -4           0
# 19            -1           0
# 20           -10           0
# 21            85           1
# 22             3           1
# 23             1           1
# 24            -2           0
# 25            26           1
# 26            -2           0
# 27            -4           0
# 28            -9           0
# 29            -3           0
# ...          ...         ...
# 45617         -1           0
# 45618         -3           0
# 45619         -3           0
# 45620          6           1
# 45621         -5           0
# 45622         20           1
# 45623         -1           0
# 45624          5           1
# 45625         58           1
# 45626         33           1
# 45627          1           1
# 45628         13           1
# 45629          0           0
# 45630         31           1
# 45631         35           1
# 45632         61           1
# 45633         -2           0
# 45634        150           1
# 45635         10           1
# 45636          0           0
# 45637          8           1
# 45638        135           1
# 45639         -4           0
# 45641         41           1
# 45642         -1           0
# 45643         -5           0
# 45644         50           1
# 45645          3           1
# 45646         -4           0
# 45647          2           1
#
# [44920 rows x 2 columns]

# %%
###Dummy variables create a

# %%
pd.get_dummies(df['ORIGIN'],prefix='origin')

# %% [markdown]
# ###Normalize values

# %%
#Normalize the data attributes for the Iris dataset
# Example from Jump Start Scikit Learn https://machinelearningmastery.com/jump-start-scikit-learn/
from sklearn.datasets import load_iris 
from sklearn import preprocessing #load the iris dataset
iris=load_iris()
X=iris.data
y=iris.target #normalize the data attributes 
normalized_X = preprocessing.normalize(X)

# %%
zip(X,normalized_X)
