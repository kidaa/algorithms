# %% [markdown]
# ##Let's work with the wine dataset we worked with before, but slightly modified. This has more instances and different target features

# %% [markdown]
# ####based on http://blog.yhathq.com/posts/classification-using-knn-and-python.html

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.neighbors import KNeighborsClassifier
from sklearn import cross_validation

# %%
import numpy as np

# %%
df = pd.read_csv("data/wine.csv")
df
# Out:
#       fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0               7.4             0.700         0.00            1.90      0.076
# 1               7.8             0.880         0.00            2.60      0.098
# 2               7.8             0.760         0.04            2.30      0.092
# 3              11.2             0.280         0.56            1.90      0.075
# 4               7.4             0.700         0.00            1.90      0.076
# 5               7.4             0.660         0.00            1.80      0.075
# 6               7.9             0.600         0.06            1.60      0.069
# 7               7.3             0.650         0.00            1.20      0.065
# 8               7.8             0.580         0.02            2.00      0.073
# 9               7.5             0.500         0.36            6.10      0.071
# 10              6.7             0.580         0.08            1.80      0.097
# 11              7.5             0.500         0.36            6.10      0.071
# 12              5.6             0.615         0.00            1.60      0.089
# 13              7.8             0.610         0.29            1.60      0.114
# 14              8.9             0.620         0.18            3.80      0.176
# 15              8.9             0.620         0.19            3.90      0.170
# 16              8.5             0.280         0.56            1.80      0.092
# 17              8.1             0.560         0.28            1.70      0.368
# 18              7.4             0.590         0.08            4.40      0.086
# 19              7.9             0.320         0.51            1.80      0.341
# 20              8.9             0.220         0.48            1.80      0.077
# 21              7.6             0.390         0.31            2.30      0.082
# 22              7.9             0.430         0.21            1.60      0.106
# 23              8.5             0.490         0.11            2.30      0.084
# 24              6.9             0.400         0.14            2.40      0.085
# 25              6.3             0.390         0.16            1.40      0.080
# 26              7.6             0.410         0.24            1.80      0.080
# 27              7.9             0.430         0.21            1.60      0.106
# 28              7.1             0.710         0.00            1.90      0.080
# 29              7.8             0.645         0.00            2.00      0.082
# ...             ...               ...          ...             ...        ...
# 6467            5.8             0.230         0.31            4.50      0.046
# 6468            6.6             0.240         0.33           10.10      0.032
# 6469            6.1             0.320         0.28            6.60      0.021
# 6470            5.0             0.200         0.40            1.90      0.015
# 6471            6.0             0.420         0.41           12.40      0.032
# 6472            5.7             0.210         0.32            1.60      0.030
# 6473            5.6             0.200         0.36            2.50      0.048
# 6474            7.4             0.220         0.26            1.20      0.035
# 6475            6.2             0.380         0.42            2.50      0.038
# 6476            5.9             0.540         0.00            0.80      0.032
# 6477            6.2             0.530         0.02            0.90      0.035
# 6478            6.6             0.340         0.40            8.10      0.046
# 6479            6.6             0.340         0.40            8.10      0.046
# 6480            5.0             0.235         0.27           11.75      0.030
# 6481            5.5             0.320         0.13            1.30      0.037
# 6482            4.9             0.470         0.17            1.90      0.035
# 6483            6.5             0.330         0.38            8.30      0.048
# 6484            6.6             0.340         0.40            8.10      0.046
# 6485            6.2             0.210         0.28            5.70      0.028
# 6486            6.2             0.410         0.22            1.90      0.023
# 6487            6.8             0.220         0.36            1.20      0.052
# 6488            4.9             0.235         0.27           11.75      0.030
# 6489            6.1             0.340         0.29            2.20      0.036
# 6490            5.7             0.210         0.32            0.90      0.038
# 6491            6.5             0.230         0.38            1.30      0.032
# 6492            6.2             0.210         0.29            1.60      0.039
# 6493            6.6             0.320         0.36            8.00      0.047
# 6494            6.5             0.240         0.19            1.20      0.041
# 6495            5.5             0.290         0.30            1.10      0.022
# 6496            6.0             0.210         0.38            0.80      0.020
#
#       free_sulfur_dioxide  total_sulfur_dioxide  density    pH  sulphates  \
# 0                      11                    34  0.99780  3.51       0.56
# 1                      25                    67  0.99680  3.20       0.68
# 2                      15                    54  0.99700  3.26       0.65
# 3                      17                    60  0.99800  3.16       0.58
# 4                      11                    34  0.99780  3.51       0.56
# 5                      13                    40  0.99780  3.51       0.56
# 6                      15                    59  0.99640  3.30       0.46
# 7                      15                    21  0.99460  3.39       0.47
# 8                       9                    18  0.99680  3.36       0.57
# 9                      17                   102  0.99780  3.35       0.80
# 10                     15                    65  0.99590  3.28       0.54
# 11                     17                   102  0.99780  3.35       0.80
# 12                     16                    59  0.99430  3.58       0.52
# 13                      9                    29  0.99740  3.26       1.56
# 14                     52                   145  0.99860  3.16       0.88
# 15                     51                   148  0.99860  3.17       0.93
# 16                     35                   103  0.99690  3.30       0.75
# 17                     16                    56  0.99680  3.11       1.28
# 18                      6                    29  0.99740  3.38       0.50
# 19                     17                    56  0.99690  3.04       1.08
# 20                     29                    60  0.99680  3.39       0.53
# 21                     23                    71  0.99820  3.52       0.65
# 22                     10                    37  0.99660  3.17       0.91
# 23                      9                    67  0.99680  3.17       0.53
# 24                     21                    40  0.99680  3.43       0.63
# 25                     11                    23  0.99550  3.34       0.56
# 26                      4                    11  0.99620  3.28       0.59
# 27                     10                    37  0.99660  3.17       0.91
# 28                     14                    35  0.99720  3.47       0.55
# 29                      8                    16  0.99640  3.38       0.59
# ...                   ...                   ...      ...   ...        ...
# 6467                   42                   124  0.99324  3.31       0.64
# 6468                    8                    81  0.99626  3.19       0.51
# 6469                   29                   132  0.99188  3.15       0.36
# 6470                   20                    98  0.98970  3.37       0.55
# 6471                   50                   179  0.99622  3.14       0.60
# 6472                   33                   122  0.99044  3.33       0.52
# 6473                   16                   125  0.99282  3.49       0.49
# 6474                   18                    97  0.99245  3.12       0.41
# 6475                   34                   117  0.99132  3.36       0.59
# 6476                   12                    82  0.99286  3.25       0.36
# 6477                    6                    81  0.99234  3.24       0.35
# 6478                   68                   170  0.99494  3.15       0.50
# 6479                   68                   170  0.99494  3.15       0.50
# 6480                   34                   118  0.99540  3.07       0.50
# 6481                   45                   156  0.99184  3.26       0.38
# 6482                   60                   148  0.98964  3.27       0.35
# 6483                   68                   174  0.99492  3.14       0.50
# 6484                   68                   170  0.99494  3.15       0.50
# 6485                   45                   121  0.99168  3.21       1.08
# 6486                    5                    56  0.98928  3.04       0.79
# 6487                   38                   127  0.99330  3.04       0.54
# 6488                   34                   118  0.99540  3.07       0.50
# 6489                   25                   100  0.98938  3.06       0.44
# 6490                   38                   121  0.99074  3.24       0.46
# 6491                   29                   112  0.99298  3.29       0.54
# 6492                   24                    92  0.99114  3.27       0.50
# 6493                   57                   168  0.99490  3.15       0.46
# 6494                   30                   111  0.99254  2.99       0.46
# 6495                   20                   110  0.98869  3.34       0.38
# 6496                   22                    98  0.98941  3.26       0.32
#
#         alcohol  quality  color  is_red  high_quality
# 0      9.400000        5    red       1             0
# 1      9.800000        5    red       1             0
# 2      9.800000        5    red       1             0
# 3      9.800000        6    red       1             0
# 4      9.400000        5    red       1             0
# 5      9.400000        5    red       1             0
# 6      9.400000        5    red       1             0
# 7     10.000000        7    red       1             1
# 8      9.500000        7    red       1             1
# 9     10.500000        5    red       1             0
# 10     9.200000        5    red       1             0
# 11    10.500000        5    red       1             0
# 12     9.900000        5    red       1             0
# 13     9.100000        5    red       1             0
# 14     9.200000        5    red       1             0
# 15     9.200000        5    red       1             0
# 16    10.500000        7    red       1             1
# 17     9.300000        5    red       1             0
# 18     9.000000        4    red       1             0
# 19     9.200000        6    red       1             0
# 20     9.400000        6    red       1             0
# 21     9.700000        5    red       1             0
# 22     9.500000        5    red       1             0
# 23     9.400000        5    red       1             0
# 24     9.700000        6    red       1             0
# 25     9.300000        5    red       1             0
# 26     9.500000        5    red       1             0
# 27     9.500000        5    red       1             0
# 28     9.400000        5    red       1             0
# 29     9.800000        6    red       1             0
# ...         ...      ...    ...     ...           ...
# 6467  10.800000        6  white       0             0
# 6468   9.800000        6  white       0             0
# 6469  11.450000        7  white       0             1
# 6470  12.050000        6  white       0             0
# 6471   9.700000        5  white       0             0
# 6472  11.900000        6  white       0             0
# 6473  10.000000        6  white       0             0
# 6474   9.700000        6  white       0             0
# 6475  11.600000        7  white       0             1
# 6476   8.800000        5  white       0             0
# 6477   9.500000        4  white       0             0
# 6478   9.533333        6  white       0             0
# 6479   9.533333        6  white       0             0
# 6480   9.400000        6  white       0             0
# 6481  10.700000        5  white       0             0
# 6482  11.500000        6  white       0             0
# 6483   9.600000        5  white       0             0
# 6484   9.550000        6  white       0             0
# 6485  12.150000        7  white       0             1
# 6486  13.000000        7  white       0             1
# 6487   9.200000        5  white       0             0
# 6488   9.400000        6  white       0             0
# 6489  11.800000        6  white       0             0
# 6490  10.600000        6  white       0             0
# 6491   9.700000        5  white       0             0
# 6492  11.200000        6  white       0             0
# 6493   9.600000        5  white       0             0
# 6494   9.400000        6  white       0             0
# 6495  12.800000        7  white       0             1
# 6496  11.800000        6  white       0             0
#
# [6497 rows x 15 columns]

# %%
df.columns
# Out:
# Index([u'fixed_acidity', u'volatile_acidity', u'citric_acid', u'residual_sugar', u'chlorides', u'free_sulfur_dioxide', u'total_sulfur_dioxide', u'density', u'pH', u'sulphates', u'alcohol', u'quality', u'color', u'is_red', u'high_quality'], dtype='object')

# %% [markdown]
# ###Instead of wine cultvar, we have the wine color (red or white), as well as a binary (is red) and high quality indicator (0 or 1)

# %%
df.high_quality.unique()
# Out:
# array([ 0.,  1.])

# %% [markdown]
# ###Let's set up our training and test sets

# %%
train, test = cross_validation.train_test_split(df[['density','sulphates','residual_sugar','high_quality']],train_size=0.75)

# %% [markdown]
# ###We'll use just three columns (dimensions) for classification

# %%
train

# %%
x_train = train[:,:3]
y_train = train[:,3]

# %%
x_test = test[:,:3]
y_test = test[:,3]

# %% [markdown]
# ###Let's start with a k of 1 to predict high quality

# %%
clf = KNeighborsClassifier(n_neighbors=1)

# %%
clf.fit(x_train,y_train)

# %%
preds = clf.predict(x_test)

# %%
accuracy = np.where(preds==y_test, 1, 0).sum() / float(len(test))

# %%
print "Accuracy: %3f" % (accuracy,)

# %% [markdown]
# ###Not bad. Let's see what happens as the k changes

# %%
results = []
for k in range(1, 51, 2):
    clf = KNeighborsClassifier(n_neighbors=k)
    clf.fit(x_train,y_train)
    preds = clf.predict(x_test)
    accuracy = np.where(preds==y_test, 1, 0).sum() / float(len(test))
    print "Neighbors: %d, Accuracy: %3f" % (k, accuracy)

    results.append([k, accuracy])

results = pd.DataFrame(results, columns=["k", "accuracy"])

plt.plot(results.k, results.accuracy)
plt.title("Accuracy with Increasing K")
plt.show()

# %% [markdown]
# ###Looks like about 80% is the best we can do. The way it plateaus, suggests there's not much more to be gained by increasing k

# %% [markdown]
# ###We can also tune this a bit by not weighting each instance the same, but decreasing the weight as the distance increases

# %%
results = []
for k in range(1, 51, 2):
    clf = KNeighborsClassifier(n_neighbors=k,weights='distance')
    clf.fit(x_train,y_train)
    preds = clf.predict(x_test)
    accuracy = np.where(preds==y_test, 1, 0).sum() / float(len(test))
    print "Neighbors: %d, Accuracy: %3f" % (k, accuracy)

    results.append([k, accuracy])

results = pd.DataFrame(results, columns=["k", "accuracy"])

plt.plot(results.k, results.accuracy)
plt.title("Accuracy with Increasing K")
plt.show()

# %% [markdown]
# ###This actually increases the accuracy of our prediction
